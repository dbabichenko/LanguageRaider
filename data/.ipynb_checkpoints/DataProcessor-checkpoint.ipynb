# %%
import uuid

# %%
f = open("conversation.xml")
lines = f.readlines()
lines
# Out:
# ['<conversation>\n',
#  '\t<turn parents="0" agent="waiter" id="1">\n',
#  '        <phrases>\n',
#  '            <phrase iscorrect="true" value="Buon giono" />\n',
#  '        <phrases>\n',
#  '    </turn>\n',
#  '    <turn parents="1" agent="customer" id="2">\n',
#  '        <phrases>\n',
#  '            <phrase iscorrect="true" value="Buon giono" />\n',
#  '            <phrase iscorrect="true" value="Salve" />\n',
#  '            <phrase iscorrect="true" value="Ciao" />\n',
#  '            <phrase iscorrect="false" value="Arrivederci" />\n',
#  '            <phrase iscorrect="false" value="Grazie" />\n',
#  '        </phrases>\n',
#  '    <turn> \n',
#  '\t<turn parents="2" agent="waiter" id="3" comment="do you have a reservation?">\n',
#  '        <phrases>\n',
#  '            <phrase iscorrect="true" value="Ha una prenotazione?" />\n',
#  '        </phrases\n',
#  '    </turn>\n',
#  '\t<turn parents="3" agent="customer" id="4" comment="if learner has reservation">\n',
# ...

# %%
phrases = []
for line in lines:
    if "<phrase is" in line:
        phrases.append(line.strip())

phrases
# Out:
# ['<phrase iscorrect="true" value="Buon giono" />',
#  '<phrase iscorrect="true" value="Buon giono" />',
#  '<phrase iscorrect="true" value="Salve" />',
#  '<phrase iscorrect="true" value="Ciao" />',
#  '<phrase iscorrect="false" value="Arrivederci" />',
#  '<phrase iscorrect="false" value="Grazie" />',
#  '<phrase iscorrect="true" value="Ha una prenotazione?" />',
#  '<phrase iscorrect="true" value="Ho una prenotazione a nome [name]" />',
#  '<phrase iscorrect="true" value="Abbiamo prenotato un tavolo per due" />',
#  '<phrase iscorrect="false" value="Ho fame" />',
#  '<phrase iscorrect="false" value="Voglio mangiare" />',
#  '<phrase iscorrect="true" value="Ha un tavolo?" />',
#  '<phrase iscorrect="true" value="Ha un tavolo per 2?" />',
#  '<phrase iscorrect="false" value="Ho fame" />',
#  '<phrase iscorrect="false" value="Voglio mangiare" />',
#  '<phrase iscorrect="true" value="No, mi dispiace" />',
#  '<phrase iscorrect="true" value="No, ci dispiace" />',
# ...

# %%
scenario_id = 1
cnt = 1
for phrase in phrases:
    temp = phrase.split('"')
    sql = "INSERT INTO dialog (scenarioID, statementID, statementText, isCorrect, isStart) VALUES ("
    sql += "'" + scenario_id + "', "
    sql += "'" + str(cnt) + "', "
    sql += "'" + temp[3] + "', "
    if temp[1] == 'true':
        sql += "1 "
    else:
        sql += "0 "
    sql = sql + ", 0);"
    cnt = cnt + 1
    #print(temp[1] + " : " + temp[3])
    print(sql)
# Out:
# INSERT INTO dialog (scenarioID, statementID, statementText, isCorrect, isStart) VALUES ('218541a6-41b2-4901-81e6-c8afa6250c02', 'e4080a92-b1ef-46dd-9f54-090e4b0aea77', 'Buon giono', 1 , 0);
# INSERT INTO dialog (scenarioID, statementID, statementText, isCorrect, isStart) VALUES ('218541a6-41b2-4901-81e6-c8afa6250c02', 'f1afd4d2-7134-4179-ad72-857a66e32458', 'Buon giono', 1 , 0);
# INSERT INTO dialog (scenarioID, statementID, statementText, isCorrect, isStart) VALUES ('218541a6-41b2-4901-81e6-c8afa6250c02', '28ad154d-be88-495a-9b92-fd8b1a4b925c', 'Salve', 1 , 0);
# INSERT INTO dialog (scenarioID, statementID, statementText, isCorrect, isStart) VALUES ('218541a6-41b2-4901-81e6-c8afa6250c02', 'ba52f91c-af8f-49ab-a029-a0fa97c40595', 'Ciao', 1 , 0);
# INSERT INTO dialog (scenarioID, statementID, statementText, isCorrect, isStart) VALUES ('218541a6-41b2-4901-81e6-c8afa6250c02', '4221aaa4-0fde-44dc-8f67-f30edf224603', 'Arrivederci', 0 , 0);
# ...
